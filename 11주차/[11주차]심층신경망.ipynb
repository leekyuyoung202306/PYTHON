# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 심층(2개이사이의 Dense층)

# %%
from tensorflow import keras

# %%
from keras.api._v2.keras import activations
# dense1 = keras.layers.Dense(100,activation = 'sigmoid',input_shape=(28*28,),name='hidden')   # hidden
dense2 = keras.layers.Dense(10,activation = 'softmax',name='output')
model = keras.Sequential([
    keras.layers.Dense(100,activation = 'sigmoid',input_shape=(28*28,),name='hidden'),   # hidden
    dense2
    ] )

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden (Dense)              (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile
# fit  : epoch 5

# %%
model.compile(loss='sparse_categorical_crossentropy',metrics='accuracy')

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(x_train,y_train),(x_test,y_test) = fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
x_train_scaled = x_train / 255.0
x_test_scaled = x_test / 255.0

# %%
x_train_scaled_2d = x_train_scaled.reshape(-1,28*28)
x_test_scaled_2d = x_test_scaled.reshape(-1,28*28)

# %%
history = model.fit(x_train_scaled_2d, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5438 - accuracy: 0.8145
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3987 - accuracy: 0.8561
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3657 - accuracy: 0.8681
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3459 - accuracy: 0.8742
# Epoch 5/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3285 - accuracy: 0.8813
# Epoch 6/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3158 - accuracy: 0.8860
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3040 - accuracy: 0.8900
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2941 - accuracy: 0.8934
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2852 - accuracy: 0.8960
# Epoch 10/10
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(1,11), history.history['loss'], label='loss')
plt.plot(range(1,11), history.history['accuracy'], label='accuracy')
plt.legend()
plt.show()

# %%
# (60000,28,28)
flatten = keras.layers.Flatten(input_shape=(28,28))
hidden1 = keras.layers.Dense(100,activation='sigmoid')
output = keras.layers.Dense(10,activation='softmax')
model = keras.Sequential([flatten,hidden1,output])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 신경망 모델을 만드는 방법
# 각 층을 만든다음
# keras.Sequence에 넣어서
model = keras.Sequential()
model.add( keras.layers.Flatten(input_shape=(28,28)) )
model.add( keras.layers.Dense(100,activation='sigmoid') )
model.add( keras.layers.Dense(10,activation='softmax') )
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 100)               78500
#
#  dense_3 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습 방법 설정
model.compile(loss='sparse_categorical_crossentropy',metrics='accuracy')

# %%
model.fit(x_train_scaled, y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.5396 - accuracy: 0.8144
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3985 - accuracy: 0.8564
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3648 - accuracy: 0.8681
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3426 - accuracy: 0.8757
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3271 - accuracy: 0.8817
