# %% [markdown]
# - GAN
#   - 생성자, 판별자의 싸움
#   - 생성자 : 랜덤한 잡음을 원래 데이터에서 샘플링한 것처럼 보이는 샘플을 만든다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 데이터 링크공유
# https://drive.google.com/drive/folders/12lUhSGWBwYrxWFGW_Ql5rTk5uDtWfao4?usp=sharing
# 원본 https://www.kaggle.com/datasets/joosthazelzet/lego-brick-images

# %%
# 각자 자신의 환경에 맞게 수정
# !unzip '/content/drive/MyDrive/lego_block_data/archive.zip' -d lego
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: lego/dataset/43857 beam 1x2 300R.png
#   inflating: lego/dataset/43857 beam 1x2 301L.png
#   inflating: lego/dataset/43857 beam 1x2 301R.png
#   inflating: lego/dataset/43857 beam 1x2 302L.png
#   inflating: lego/dataset/43857 beam 1x2 302R.png
#   inflating: lego/dataset/43857 beam 1x2 303L.png
#   inflating: lego/dataset/43857 beam 1x2 303R.png
#   inflating: lego/dataset/43857 beam 1x2 304L.png
#   inflating: lego/dataset/43857 beam 1x2 304R.png
#   inflating: lego/dataset/43857 beam 1x2 305L.png
#   inflating: lego/dataset/43857 beam 1x2 305R.png
#   inflating: lego/dataset/43857 beam 1x2 306L.png
#   inflating: lego/dataset/43857 beam 1x2 306R.png
#   inflating: lego/dataset/43857 beam 1x2 307L.png
#   inflating: lego/dataset/43857 beam 1x2 307R.png
#   inflating: lego/dataset/43857 beam 1x2 308L.png
#   inflating: lego/dataset/43857 beam 1x2 308R.png
#   inflating: lego/dataset/43857 beam 1x2 309L.png
#   inflating: lego/dataset/43857 beam 1x2 309R.png
#   inflating: lego/dataset/43857 beam 1x2 310L.png
#   inflating: lego/dataset/43857 beam 1x2 310R.png
#   inflating: lego/dataset/43857 beam 1x2 311L.png
#   inflating: lego/dataset/43857 beam 1x2 311R.png
#   inflating: lego/dataset/43857 beam 1x2 312L.png
#   inflating: lego/dataset/43857 beam 1x2 312R.png
#   inflating: lego/dataset/43857 beam 1x2 313L.png
#   inflating: lego/dataset/43857 beam 1x2 313R.png
#   inflating: lego/dataset/43857 beam 1x2 314L.png
#   inflating: lego/dataset/43857 beam 1x2 314R.png
#   inflating: lego/dataset/43857 beam 1x2 315L.png
#   inflating: lego/dataset/43857 beam 1x2 315R.png
#   inflating: lego/dataset/43857 beam 1x2 316L.png
#   inflating: lego/dataset/43857 beam 1x2 316R.png
#   inflating: lego/dataset/43857 beam 1x2 317L.png
#   inflating: lego/dataset/43857 beam 1x2 317R.png
#   inflating: lego/dataset/43857 beam 1x2 318L.png
#   inflating: lego/dataset/43857 beam 1x2 318R.png
#   inflating: lego/dataset/43857 beam 1x2 319L.png
#   inflating: lego/dataset/43857 beam 1x2 319R.png
#   inflating: lego/dataset/43857 beam 1x2 320L.png
#   inflating: lego/dataset/43857 beam 1x2 320R.png
#   inflating: lego/dataset/43857 beam 1x2 321L.png
#   inflating: lego/dataset/43857 beam 1x2 321R.png
#   inflating: lego/dataset/43857 beam 1x2 322L.png
#   inflating: lego/dataset/43857 beam 1x2 322R.png
#   inflating: lego/dataset/43857 beam 1x2 323L.png
#   inflating: lego/dataset/43857 beam 1x2 323R.png
#   inflating: lego/dataset/43857 beam 1x2 324L.png
#   inflating: lego/dataset/43857 beam 1x2 324R.png
#   inflating: lego/dataset/43857 beam 1x2 325L.png
#   inflating: lego/dataset/43857 beam 1x2 325R.png
#   inflating: lego/dataset/43857 beam 1x2 326L.png
#   inflating: lego/dataset/43857 beam 1x2 326R.png
#   inflating: lego/dataset/43857 beam 1x2 327L.png
#   inflating: lego/dataset/43857 beam 1x2 327R.png
#   inflating: lego/dataset/43857 beam 1x2 328L.png
#   inflating: lego/dataset/43857 beam 1x2 328R.png
#   inflating: lego/dataset/43857 beam 1x2 329L.png
#   inflating: lego/dataset/43857 beam 1x2 329R.png
#   inflating: lego/dataset/43857 beam 1x2 330L.png
#   inflating: lego/dataset/43857 beam 1x2 330R.png
#   inflating: lego/dataset/43857 beam 1x2 331L.png
#   inflating: lego/dataset/43857 beam 1x2 331R.png
#   inflating: lego/dataset/43857 beam 1x2 332L.png
#   inflating: lego/dataset/43857 beam 1x2 332R.png
#   inflating: lego/dataset/43857 beam 1x2 333L.png
#   inflating: lego/dataset/43857 beam 1x2 333R.png
#   inflating: lego/dataset/43857 beam 1x2 334L.png
#   inflating: lego/dataset/43857 beam 1x2 334R.png
#   inflating: lego/dataset/43857 beam 1x2 335L.png
#   inflating: lego/dataset/43857 beam 1x2 335R.png
#   inflating: lego/dataset/43857 beam 1x2 336L.png
#   inflating: lego/dataset/43857 beam 1x2 336R.png
#   inflating: lego/dataset/43857 beam 1x2 337L.png
#   inflating: lego/dataset/43857 beam 1x2 337R.png
#   inflating: lego/dataset/43857 beam 1x2 338L.png
#   inflating: lego/dataset/43857 beam 1x2 338R.png
#   inflating: lego/dataset/43857 beam 1x2 339L.png
#   inflating: lego/dataset/43857 beam 1x2 339R.png
#   inflating: lego/dataset/43857 beam 1x2 340L.png
#   inflating: lego/dataset/43857 beam 1x2 340R.png
#   inflating: lego/dataset/43857 beam 1x2 341L.png
#   inflating: lego/dataset/43857 beam 1x2 341R.png
#   inflating: lego/dataset/43857 beam 1x2 342L.png
#   inflating: lego/dataset/43857 beam 1x2 342R.png
#   inflating: lego/dataset/43857 beam 1x2 343L.png
#   inflating: lego/dataset/43857 beam 1x2 343R.png
#   inflating: lego/dataset/43857 beam 1x2 344L.png
#   inflating: lego/dataset/43857 beam 1x2 344R.png
#   inflating: lego/dataset/43857 beam 1x2 345L.png
#   inflating: lego/dataset/43857 beam 1x2 345R.png
#   inflating: lego/dataset/43857 beam 1x2 346L.png
#   inflating: lego/dataset/43857 beam 1x2 346R.png
#   inflating: lego/dataset/43857 beam 1x2 347L.png
#   inflating: lego/dataset/43857 beam 1x2 347R.png
#   inflating: lego/dataset/43857 beam 1x2 348L.png
#   inflating: lego/dataset/43857 beam 1x2 348R.png
#   inflating: lego/dataset/43857 beam 1x2 349L.png
#   inflating: lego/dataset/43857 beam 1x2 349R.png
#   inflating: lego/dataset/43857 beam 1x2 350L.png
#   inflating: lego/dataset/43857 beam 1x2 350R.png
#   inflating: lego/dataset/43857 beam 1x2 351L.png
#   inflating: lego/dataset/43857 beam 1x2 351R.png
#   inflating: lego/dataset/43857 beam 1x2 352L.png
#   inflating: lego/dataset/43857 beam 1x2 352R.png
#   inflating: lego/dataset/43857 beam 1x2 353L.png
#   inflating: lego/dataset/43857 beam 1x2 353R.png
#   inflating: lego/dataset/43857 beam 1x2 354L.png
#   inflating: lego/dataset/43857 beam 1x2 354R.png
#   inflating: lego/dataset/43857 beam 1x2 355L.png
#   inflating: lego/dataset/43857 beam 1x2 355R.png
#   inflating: lego/dataset/43857 beam 1x2 356L.png
#   inflating: lego/dataset/43857 beam 1x2 356R.png
#   inflating: lego/dataset/43857 beam 1x2 357L.png
#   inflating: lego/dataset/43857 beam 1x2 357R.png
#   inflating: lego/dataset/43857 beam 1x2 358L.png
#   inflating: lego/dataset/43857 beam 1x2 358R.png
#   inflating: lego/dataset/43857 beam 1x2 359L.png
#   inflating: lego/dataset/43857 beam 1x2 359R.png
#   inflating: lego/dataset/43857 beam 1x2 360L.png
#   inflating: lego/dataset/43857 beam 1x2 360R.png
#   inflating: lego/dataset/43857 beam 1x2 361L.png
#   inflating: lego/dataset/43857 beam 1x2 361R.png
#   inflating: lego/dataset/43857 beam 1x2 362L.png
#   inflating: lego/dataset/43857 beam 1x2 362R.png
#   inflating: lego/dataset/43857 beam 1x2 363L.png
#   inflating: lego/dataset/43857 beam 1x2 363R.png
#   inflating: lego/dataset/43857 beam 1x2 364L.png
#   inflating: lego/dataset/43857 beam 1x2 364R.png
#   inflating: lego/dataset/43857 beam 1x2 365L.png
#   inflating: lego/dataset/43857 beam 1x2 365R.png
#   inflating: lego/dataset/43857 beam 1x2 366L.png
#   inflating: lego/dataset/43857 beam 1x2 366R.png
#   inflating: lego/dataset/43857 beam 1x2 367L.png
#   inflating: lego/dataset/43857 beam 1x2 367R.png
#   inflating: lego/dataset/43857 beam 1x2 368L.png
#   inflating: lego/dataset/43857 beam 1x2 368R.png
#   inflating: lego/dataset/43857 beam 1x2 369L.png
#   inflating: lego/dataset/43857 beam 1x2 369R.png
#   inflating: lego/dataset/43857 beam 1x2 370L.png
#   inflating: lego/dataset/43857 beam 1x2 370R.png
#   inflating: lego/dataset/43857 beam 1x2 371L.png
#   inflating: lego/dataset/43857 beam 1x2 371R.png
#   inflating: lego/dataset/43857 beam 1x2 372L.png
#   inflating: lego/dataset/43857 beam 1x2 372R.png
#   inflating: lego/dataset/43857 beam 1x2 373L.png
#   inflating: lego/dataset/43857 beam 1x2 373R.png
#   inflating: lego/dataset/43857 beam 1x2 374L.png
#   inflating: lego/dataset/43857 beam 1x2 374R.png
#   inflating: lego/dataset/43857 beam 1x2 375L.png
#   inflating: lego/dataset/43857 beam 1x2 375R.png
#   inflating: lego/dataset/43857 beam 1x2 376L.png
#   inflating: lego/dataset/43857 beam 1x2 376R.png
#   inflating: lego/dataset/43857 beam 1x2 377L.png
#   inflating: lego/dataset/43857 beam 1x2 377R.png
#   inflating: lego/dataset/43857 beam 1x2 378L.png
#   inflating: lego/dataset/43857 beam 1x2 378R.png
#   inflating: lego/dataset/43857 beam 1x2 379L.png
#   inflating: lego/dataset/43857 beam 1x2 379R.png
#   inflating: lego/dataset/43857 beam 1x2 380L.png
#   inflating: lego/dataset/43857 beam 1x2 380R.png
#   inflating: lego/dataset/43857 beam 1x2 381L.png
#   inflating: lego/dataset/43857 beam 1x2 381R.png
#   inflating: lego/dataset/43857 beam 1x2 382L.png
#   inflating: lego/dataset/43857 beam 1x2 382R.png
#   inflating: lego/dataset/43857 beam 1x2 383L.png
#   inflating: lego/dataset/43857 beam 1x2 383R.png
#   inflating: lego/dataset/43857 beam 1x2 384L.png
#   inflating: lego/dataset/43857 beam 1x2 384R.png
#   inflating: lego/dataset/43857 beam 1x2 385L.png
#   inflating: lego/dataset/43857 beam 1x2 385R.png
#   inflating: lego/dataset/43857 beam 1x2 386L.png
#   inflating: lego/dataset/43857 beam 1x2 386R.png
#   inflating: lego/dataset/43857 beam 1x2 387L.png
#   inflating: lego/dataset/43857 beam 1x2 387R.png
#   inflating: lego/dataset/43857 beam 1x2 388L.png
#   inflating: lego/dataset/43857 beam 1x2 388R.png
#   inflating: lego/dataset/43857 beam 1x2 389L.png
#   inflating: lego/dataset/43857 beam 1x2 389R.png
#   inflating: lego/dataset/43857 beam 1x2 390L.png
#   inflating: lego/dataset/43857 beam 1x2 390R.png
#   inflating: lego/dataset/43857 beam 1x2 391L.png
#   inflating: lego/dataset/43857 beam 1x2 391R.png
#   inflating: lego/dataset/43857 beam 1x2 392L.png
#   inflating: lego/dataset/43857 beam 1x2 392R.png
#   inflating: lego/dataset/43857 beam 1x2 393L.png
#   inflating: lego/dataset/43857 beam 1x2 393R.png
#   inflating: lego/dataset/43857 beam 1x2 394L.png
#   inflating: lego/dataset/43857 beam 1x2 394R.png
#   inflating: lego/dataset/43857 beam 1x2 395L.png
#   inflating: lego/dataset/43857 beam 1x2 395R.png
#   inflating: lego/dataset/43857 beam 1x2 396L.png
#   inflating: lego/dataset/43857 beam 1x2 396R.png
#   inflating: lego/dataset/43857 beam 1x2 397L.png
#   inflating: lego/dataset/43857 beam 1x2 397R.png
#   inflating: lego/dataset/43857 beam 1x2 398L.png
#   inflating: lego/dataset/43857 beam 1x2 398R.png
#   inflating: lego/dataset/43857 beam 1x2 399L.png
#   inflating: lego/dataset/43857 beam 1x2 399R.png
#   inflating: lego/dataset/4490 brick bow 1x3 000L.png
#   inflating: lego/dataset/4490 brick bow 1x3 000R.png
#   inflating: lego/dataset/4490 brick bow 1x3 001L.png
#   inflating: lego/dataset/4490 brick bow 1x3 001R.png
#   inflating: lego/dataset/4490 brick bow 1x3 002L.png
#   inflating: lego/dataset/4490 brick bow 1x3 002R.png
#   inflating: lego/dataset/4490 brick bow 1x3 003L.png
#   inflating: lego/dataset/4490 brick bow 1x3 003R.png
#   inflating: lego/dataset/4490 brick bow 1x3 004L.png
#   inflating: lego/dataset/4490 brick bow 1x3 004R.png
#   inflating: lego/dataset/4490 brick bow 1x3 005L.png
#   inflating: lego/dataset/4490 brick bow 1x3 005R.png
#   inflating: lego/dataset/4490 brick bow 1x3 006L.png
#   inflating: lego/dataset/4490 brick bow 1x3 006R.png
#   inflating: lego/dataset/4490 brick bow 1x3 007L.png
#   inflating: lego/dataset/4490 brick bow 1x3 007R.png
#   inflating: lego/dataset/4490 brick bow 1x3 008L.png
#   inflating: lego/dataset/4490 brick bow 1x3 008R.png
#   inflating: lego/dataset/4490 brick bow 1x3 009L.png
#   inflating: lego/dataset/4490 brick bow 1x3 009R.png
#   inflating: lego/dataset/4490 brick bow 1x3 010L.png
#   inflating: lego/dataset/4490 brick bow 1x3 010R.png
#   inflating: lego/dataset/4490 brick bow 1x3 011L.png
#   inflating: lego/dataset/4490 brick bow 1x3 011R.png
#   inflating: lego/dataset/4490 brick bow 1x3 012L.png
#   inflating: lego/dataset/4490 brick bow 1x3 012R.png
#   inflating: lego/dataset/4490 brick bow 1x3 013L.png
#   inflating: lego/dataset/4490 brick bow 1x3 013R.png
#   inflating: lego/dataset/4490 brick bow 1x3 014L.png
#   inflating: lego/dataset/4490 brick bow 1x3 014R.png
#   inflating: lego/dataset/4490 brick bow 1x3 015L.png
#   inflating: lego/dataset/4490 brick bow 1x3 015R.png
#   inflating: lego/dataset/4490 brick bow 1x3 016L.png
#   inflating: lego/dataset/4490 brick bow 1x3 016R.png
#   inflating: lego/dataset/4490 brick bow 1x3 017L.png
#   inflating: lego/dataset/4490 brick bow 1x3 017R.png
#   inflating: lego/dataset/4490 brick bow 1x3 018L.png
#   inflating: lego/dataset/4490 brick bow 1x3 018R.png
#   inflating: lego/dataset/4490 brick bow 1x3 019L.png
#   inflating: lego/dataset/4490 brick bow 1x3 019R.png
#   inflating: lego/dataset/4490 brick bow 1x3 020L.png
#   inflating: lego/dataset/4490 brick bow 1x3 020R.png
#   inflating: lego/dataset/4490 brick bow 1x3 021L.png
#   inflating: lego/dataset/4490 brick bow 1x3 021R.png
#   inflating: lego/dataset/4490 brick bow 1x3 022L.png
#   inflating: lego/dataset/4490 brick bow 1x3 022R.png
#   inflating: lego/dataset/4490 brick bow 1x3 023L.png
#   inflating: lego/dataset/4490 brick bow 1x3 023R.png
#   inflating: lego/dataset/4490 brick bow 1x3 024L.png
#   inflating: lego/dataset/4490 brick bow 1x3 024R.png
#   inflating: lego/dataset/4490 brick bow 1x3 025L.png
#   inflating: lego/dataset/4490 brick bow 1x3 025R.png
#   inflating: lego/dataset/4490 brick bow 1x3 026L.png
#   inflating: lego/dataset/4490 brick bow 1x3 026R.png
#   inflating: lego/dataset/4490 brick bow 1x3 027L.png
#   inflating: lego/dataset/4490 brick bow 1x3 027R.png
#   inflating: lego/dataset/4490 brick bow 1x3 028L.png
#   inflating: lego/dataset/4490 brick bow 1x3 028R.png
#   inflating: lego/dataset/4490 brick bow 1x3 029L.png
#   inflating: lego/dataset/4490 brick bow 1x3 029R.png
#   inflating: lego/dataset/4490 brick bow 1x3 030L.png
#   inflating: lego/dataset/4490 brick bow 1x3 030R.png
#   inflating: lego/dataset/4490 brick bow 1x3 031L.png
#   inflating: lego/dataset/4490 brick bow 1x3 031R.png
#   inflating: lego/dataset/4490 brick bow 1x3 032L.png
#   inflating: lego/dataset/4490 brick bow 1x3 032R.png
#   inflating: lego/dataset/4490 brick bow 1x3 033L.png
#   inflating: lego/dataset/4490 brick bow 1x3 033R.png
#   inflating: lego/dataset/4490 brick bow 1x3 034L.png
#   inflating: lego/dataset/4490 brick bow 1x3 034R.png
#   inflating: lego/dataset/4490 brick bow 1x3 035L.png
#   inflating: lego/dataset/4490 brick bow 1x3 035R.png
#   inflating: lego/dataset/4490 brick bow 1x3 036L.png
#   inflating: lego/dataset/4490 brick bow 1x3 036R.png
#   inflating: lego/dataset/4490 brick bow 1x3 037L.png
#   inflating: lego/dataset/4490 brick bow 1x3 037R.png
#   inflating: lego/dataset/4490 brick bow 1x3 038L.png
#   inflating: lego/dataset/4490 brick bow 1x3 038R.png
#   inflating: lego/dataset/4490 brick bow 1x3 039L.png
#   inflating: lego/dataset/4490 brick bow 1x3 039R.png
#   inflating: lego/dataset/4490 brick bow 1x3 040L.png
#   inflating: lego/dataset/4490 brick bow 1x3 040R.png
#   inflating: lego/dataset/4490 brick bow 1x3 041L.png
#   inflating: lego/dataset/4490 brick bow 1x3 041R.png
#   inflating: lego/dataset/4490 brick bow 1x3 042L.png
#   inflating: lego/dataset/4490 brick bow 1x3 042R.png
#   inflating: lego/dataset/4490 brick bow 1x3 043L.png
#   inflating: lego/dataset/4490 brick bow 1x3 043R.png
#   inflating: lego/dataset/4490 brick bow 1x3 044L.png
#   inflating: lego/dataset/4490 brick bow 1x3 044R.png
#   inflating: lego/dataset/4490 brick bow 1x3 045L.png
#   inflating: lego/dataset/4490 brick bow 1x3 045R.png
#   inflating: lego/dataset/4490 brick bow 1x3 046L.png
#   inflating: lego/dataset/4490 brick bow 1x3 046R.png
#   inflating: lego/dataset/4490 brick bow 1x3 047L.png
#   inflating: lego/dataset/4490 brick bow 1x3 047R.png
#   inflating: lego/dataset/4490 brick bow 1x3 048L.png
#   inflating: lego/dataset/4490 brick bow 1x3 048R.png
#   inflating: lego/dataset/4490 brick bow 1x3 049L.png
#   inflating: lego/dataset/4490 brick bow 1x3 049R.png
#   inflating: lego/dataset/4490 brick bow 1x3 050L.png
#   inflating: lego/dataset/4490 brick bow 1x3 050R.png
#   inflating: lego/dataset/4490 brick bow 1x3 051L.png
#   inflating: lego/dataset/4490 brick bow 1x3 051R.png
#   inflating: lego/dataset/4490 brick bow 1x3 052L.png
#   inflating: lego/dataset/4490 brick bow 1x3 052R.png
#   inflating: lego/dataset/4490 brick bow 1x3 053L.png
#   inflating: lego/dataset/4490 brick bow 1x3 053R.png
#   inflating: lego/dataset/4490 brick bow 1x3 054L.png
#   inflating: lego/dataset/4490 brick bow 1x3 054R.png
#   inflating: lego/dataset/4490 brick bow 1x3 055L.png
#   inflating: lego/dataset/4490 brick bow 1x3 055R.png
#   inflating: lego/dataset/4490 brick bow 1x3 056L.png
#   inflating: lego/dataset/4490 brick bow 1x3 056R.png
#   inflating: lego/dataset/4490 brick bow 1x3 057L.png
#   inflating: lego/dataset/4490 brick bow 1x3 057R.png
#   inflating: lego/dataset/4490 brick bow 1x3 058L.png
#   inflating: lego/dataset/4490 brick bow 1x3 058R.png
#   inflating: lego/dataset/4490 brick bow 1x3 059L.png
#   inflating: lego/dataset/4490 brick bow 1x3 059R.png
#   inflating: lego/dataset/4490 brick bow 1x3 060L.png
#   inflating: lego/dataset/4490 brick bow 1x3 060R.png
#   inflating: lego/dataset/4490 brick bow 1x3 061L.png
#   inflating: lego/dataset/4490 brick bow 1x3 061R.png
#   inflating: lego/dataset/4490 brick bow 1x3 062L.png
#   inflating: lego/dataset/4490 brick bow 1x3 062R.png
#   inflating: lego/dataset/4490 brick bow 1x3 063L.png
#   inflating: lego/dataset/4490 brick bow 1x3 063R.png
#   inflating: lego/dataset/4490 brick bow 1x3 064L.png
#   inflating: lego/dataset/4490 brick bow 1x3 064R.png
#   inflating: lego/dataset/4490 brick bow 1x3 065L.png
#   inflating: lego/dataset/4490 brick bow 1x3 065R.png
#   inflating: lego/dataset/4490 brick bow 1x3 066L.png
#   inflating: lego/dataset/4490 brick bow 1x3 066R.png
#   inflating: lego/dataset/4490 brick bow 1x3 067L.png
#   inflating: lego/dataset/4490 brick bow 1x3 067R.png
#   inflating: lego/dataset/4490 brick bow 1x3 068L.png
#   inflating: lego/dataset/4490 brick bow 1x3 068R.png
#   inflating: lego/dataset/4490 brick bow 1x3 069L.png
#   inflating: lego/dataset/4490 brick bow 1x3 069R.png
#   inflating: lego/dataset/4490 brick bow 1x3 070L.png
#   inflating: lego/dataset/4490 brick bow 1x3 070R.png
#   inflating: lego/dataset/4490 brick bow 1x3 071L.png
#   inflating: lego/dataset/4490 brick bow 1x3 071R.png
#   inflating: lego/dataset/4490 brick bow 1x3 072L.png
#   inflating: lego/dataset/4490 brick bow 1x3 072R.png
#   inflating: lego/dataset/4490 brick bow 1x3 073L.png
#   inflating: lego/dataset/4490 brick bow 1x3 073R.png
#   inflating: lego/dataset/4490 brick bow 1x3 074L.png
#   inflating: lego/dataset/4490 brick bow 1x3 074R.png
#   inflating: lego/dataset/4490 brick bow 1x3 075L.png
#   inflating: lego/dataset/4490 brick bow 1x3 075R.png
#   inflating: lego/dataset/4490 brick bow 1x3 076L.png
#   inflating: lego/dataset/4490 brick bow 1x3 076R.png
#   inflating: lego/dataset/4490 brick bow 1x3 077L.png
#   inflating: lego/dataset/4490 brick bow 1x3 077R.png
#   inflating: lego/dataset/4490 brick bow 1x3 078L.png
#   inflating: lego/dataset/4490 brick bow 1x3 078R.png
#   inflating: lego/dataset/4490 brick bow 1x3 079L.png
#   inflating: lego/dataset/4490 brick bow 1x3 079R.png
#   inflating: lego/dataset/4490 brick bow 1x3 080L.png
#   inflating: lego/dataset/4490 brick bow 1x3 080R.png
#   inflating: lego/dataset/4490 brick bow 1x3 081L.png
#   inflating: lego/dataset/4490 brick bow 1x3 081R.png
#   inflating: lego/dataset/4490 brick bow 1x3 082L.png
#   inflating: lego/dataset/4490 brick bow 1x3 082R.png
#   inflating: lego/dataset/4490 brick bow 1x3 083L.png
#   inflating: lego/dataset/4490 brick bow 1x3 083R.png
#   inflating: lego/dataset/4490 brick bow 1x3 084L.png
#   inflating: lego/dataset/4490 brick bow 1x3 084R.png
#   inflating: lego/dataset/4490 brick bow 1x3 085L.png
#   inflating: lego/dataset/4490 brick bow 1x3 085R.png
#   inflating: lego/dataset/4490 brick bow 1x3 086L.png
#   inflating: lego/dataset/4490 brick bow 1x3 086R.png
#   inflating: lego/dataset/4490 brick bow 1x3 087L.png
#   inflating: lego/dataset/4490 brick bow 1x3 087R.png
#   inflating: lego/dataset/4490 brick bow 1x3 088L.png
#   inflating: lego/dataset/4490 brick bow 1x3 088R.png
#   inflating: lego/dataset/4490 brick bow 1x3 089L.png
#   inflating: lego/dataset/4490 brick bow 1x3 089R.png
#   inflating: lego/dataset/4490 brick bow 1x3 090L.png
#   inflating: lego/dataset/4490 brick bow 1x3 090R.png
#   inflating: lego/dataset/4490 brick bow 1x3 091L.png
#   inflating: lego/dataset/4490 brick bow 1x3 091R.png
#   inflating: lego/dataset/4490 brick bow 1x3 092L.png
#   inflating: lego/dataset/4490 brick bow 1x3 092R.png
#   inflating: lego/dataset/4490 brick bow 1x3 093L.png
#   inflating: lego/dataset/4490 brick bow 1x3 093R.png
#   inflating: lego/dataset/4490 brick bow 1x3 094L.png
#   inflating: lego/dataset/4490 brick bow 1x3 094R.png
#   inflating: lego/dataset/4490 brick bow 1x3 095L.png
#   inflating: lego/dataset/4490 brick bow 1x3 095R.png
#   inflating: lego/dataset/4490 brick bow 1x3 096L.png
#   inflating: lego/dataset/4490 brick bow 1x3 096R.png
#   inflating: lego/dataset/4490 brick bow 1x3 097L.png
#   inflating: lego/dataset/4490 brick bow 1x3 097R.png
#   inflating: lego/dataset/4490 brick bow 1x3 098L.png
#   inflating: lego/dataset/4490 brick bow 1x3 098R.png
#   inflating: lego/dataset/4490 brick bow 1x3 099L.png
#   inflating: lego/dataset/4490 brick bow 1x3 099R.png
#   inflating: lego/dataset/4490 brick bow 1x3 100L.png
#   inflating: lego/dataset/4490 brick bow 1x3 100R.png
#   inflating: lego/dataset/4490 brick bow 1x3 101L.png
#   inflating: lego/dataset/4490 brick bow 1x3 101R.png
#   inflating: lego/dataset/4490 brick bow 1x3 102L.png
#   inflating: lego/dataset/4490 brick bow 1x3 102R.png
#   inflating: lego/dataset/4490 brick bow 1x3 103L.png
#   inflating: lego/dataset/4490 brick bow 1x3 103R.png
#   inflating: lego/dataset/4490 brick bow 1x3 104L.png
#   inflating: lego/dataset/4490 brick bow 1x3 104R.png
#   inflating: lego/dataset/4490 brick bow 1x3 105L.png
#   inflating: lego/dataset/4490 brick bow 1x3 105R.png
#   inflating: lego/dataset/4490 brick bow 1x3 106L.png
#   inflating: lego/dataset/4490 brick bow 1x3 106R.png
#   inflating: lego/dataset/4490 brick bow 1x3 107L.png
#   inflating: lego/dataset/4490 brick bow 1x3 107R.png
#   inflating: lego/dataset/4490 brick bow 1x3 108L.png
#   inflating: lego/dataset/4490 brick bow 1x3 108R.png
#   inflating: lego/dataset/4490 brick bow 1x3 109L.png
#   inflating: lego/dataset/4490 brick bow 1x3 109R.png
#   inflating: lego/dataset/4490 brick bow 1x3 110L.png
#   inflating: lego/dataset/4490 brick bow 1x3 110R.png
#   inflating: lego/dataset/4490 brick bow 1x3 111L.png
#   inflating: lego/dataset/4490 brick bow 1x3 111R.png
#   inflating: lego/dataset/4490 brick bow 1x3 112L.png
#   inflating: lego/dataset/4490 brick bow 1x3 112R.png
#   inflating: lego/dataset/4490 brick bow 1x3 113L.png
#   inflating: lego/dataset/4490 brick bow 1x3 113R.png
#   inflating: lego/dataset/4490 brick bow 1x3 114L.png
#   inflating: lego/dataset/4490 brick bow 1x3 114R.png
#   inflating: lego/dataset/4490 brick bow 1x3 115L.png
#   inflating: lego/dataset/4490 brick bow 1x3 115R.png
#   inflating: lego/dataset/4490 brick bow 1x3 116L.png
#   inflating: lego/dataset/4490 brick bow 1x3 116R.png
#   inflating: lego/dataset/4490 brick bow 1x3 117L.png
#   inflating: lego/dataset/4490 brick bow 1x3 117R.png
#   inflating: lego/dataset/4490 brick bow 1x3 118L.png
#   inflating: lego/dataset/4490 brick bow 1x3 118R.png
#   inflating: lego/dataset/4490 brick bow 1x3 119L.png
#   inflating: lego/dataset/4490 brick bow 1x3 119R.png
#   inflating: lego/dataset/4490 brick bow 1x3 120L.png
#   inflating: lego/dataset/4490 brick bow 1x3 120R.png
#   inflating: lego/dataset/4490 brick bow 1x3 121L.png
#   inflating: lego/dataset/4490 brick bow 1x3 121R.png
#   inflating: lego/dataset/4490 brick bow 1x3 122L.png
#   inflating: lego/dataset/4490 brick bow 1x3 122R.png
#   inflating: lego/dataset/4490 brick bow 1x3 123L.png
#   inflating: lego/dataset/4490 brick bow 1x3 123R.png
#   inflating: lego/dataset/4490 brick bow 1x3 124L.png
#   inflating: lego/dataset/4490 brick bow 1x3 124R.png
#   inflating: lego/dataset/4490 brick bow 1x3 125L.png
#   inflating: lego/dataset/4490 brick bow 1x3 125R.png
#   inflating: lego/dataset/4490 brick bow 1x3 126L.png
#   inflating: lego/dataset/4490 brick bow 1x3 126R.png
#   inflating: lego/dataset/4490 brick bow 1x3 127L.png
#   inflating: lego/dataset/4490 brick bow 1x3 127R.png
#   inflating: lego/dataset/4490 brick bow 1x3 128L.png
#   inflating: lego/dataset/4490 brick bow 1x3 128R.png
#   inflating: lego/dataset/4490 brick bow 1x3 129L.png
#   inflating: lego/dataset/4490 brick bow 1x3 129R.png
#   inflating: lego/dataset/4490 brick bow 1x3 130L.png
#   inflating: lego/dataset/4490 brick bow 1x3 130R.png
#   inflating: lego/dataset/4490 brick bow 1x3 131L.png
#   inflating: lego/dataset/4490 brick bow 1x3 131R.png
#   inflating: lego/dataset/4490 brick bow 1x3 132L.png
#   inflating: lego/dataset/4490 brick bow 1x3 132R.png
#   inflating: lego/dataset/4490 brick bow 1x3 133L.png
#   inflating: lego/dataset/4490 brick bow 1x3 133R.png
#   inflating: lego/dataset/4490 brick bow 1x3 134L.png
#   inflating: lego/dataset/4490 brick bow 1x3 134R.png
#   inflating: lego/dataset/4490 brick bow 1x3 135L.png
#   inflating: lego/dataset/4490 brick bow 1x3 135R.png
#   inflating: lego/dataset/4490 brick bow 1x3 136L.png
#   inflating: lego/dataset/4490 brick bow 1x3 136R.png
#   inflating: lego/dataset/4490 brick bow 1x3 137L.png
#   inflating: lego/dataset/4490 brick bow 1x3 137R.png
#   inflating: lego/dataset/4490 brick bow 1x3 138L.png
#   inflating: lego/dataset/4490 brick bow 1x3 138R.png
#   inflating: lego/dataset/4490 brick bow 1x3 139L.png
#   inflating: lego/dataset/4490 brick bow 1x3 139R.png
#   inflating: lego/dataset/4490 brick bow 1x3 140L.png
#   inflating: lego/dataset/4490 brick bow 1x3 140R.png
#   inflating: lego/dataset/4490 brick bow 1x3 141L.png
#   inflating: lego/dataset/4490 brick bow 1x3 141R.png
#   inflating: lego/dataset/4490 brick bow 1x3 142L.png
#   inflating: lego/dataset/4490 brick bow 1x3 142R.png
#   inflating: lego/dataset/4490 brick bow 1x3 143L.png
#   inflating: lego/dataset/4490 brick bow 1x3 143R.png
#   inflating: lego/dataset/4490 brick bow 1x3 144L.png
#   inflating: lego/dataset/4490 brick bow 1x3 144R.png
#   inflating: lego/dataset/4490 brick bow 1x3 145L.png
#   inflating: lego/dataset/4490 brick bow 1x3 145R.png
#   inflating: lego/dataset/4490 brick bow 1x3 146L.png
#   inflating: lego/dataset/4490 brick bow 1x3 146R.png
#   inflating: lego/dataset/4490 brick bow 1x3 147L.png
#   inflating: lego/dataset/4490 brick bow 1x3 147R.png
#   inflating: lego/dataset/4490 brick bow 1x3 148L.png
#   inflating: lego/dataset/4490 brick bow 1x3 148R.png
#   inflating: lego/dataset/4490 brick bow 1x3 149L.png
#   inflating: lego/dataset/4490 brick bow 1x3 149R.png
#   inflating: lego/dataset/4490 brick bow 1x3 150L.png
#   inflating: lego/dataset/4490 brick bow 1x3 150R.png
#   inflating: lego/dataset/4490 brick bow 1x3 151L.png
#   inflating: lego/dataset/4490 brick bow 1x3 151R.png
#   inflating: lego/dataset/4490 brick bow 1x3 152L.png
#   inflating: lego/dataset/4490 brick bow 1x3 152R.png
#   inflating: lego/dataset/4490 brick bow 1x3 153L.png
#   inflating: lego/dataset/4490 brick bow 1x3 153R.png
#   inflating: lego/dataset/4490 brick bow 1x3 154L.png
#   inflating: lego/dataset/4490 brick bow 1x3 154R.png
#   inflating: lego/dataset/4490 brick bow 1x3 155L.png
#   inflating: lego/dataset/4490 brick bow 1x3 155R.png
#   inflating: lego/dataset/4490 brick bow 1x3 156L.png
#   inflating: lego/dataset/4490 brick bow 1x3 156R.png
#   inflating: lego/dataset/4490 brick bow 1x3 157L.png
#   inflating: lego/dataset/4490 brick bow 1x3 157R.png
#   inflating: lego/dataset/4490 brick bow 1x3 158L.png
#   inflating: lego/dataset/4490 brick bow 1x3 158R.png
#   inflating: lego/dataset/4490 brick bow 1x3 159L.png
#   inflating: lego/dataset/4490 brick bow 1x3 159R.png
#   inflating: lego/dataset/4490 brick bow 1x3 160L.png
#   inflating: lego/dataset/4490 brick bow 1x3 160R.png
#   inflating: lego/dataset/4490 brick bow 1x3 161L.png
#   inflating: lego/dataset/4490 brick bow 1x3 161R.png
#   inflating: lego/dataset/4490 brick bow 1x3 162L.png
#   inflating: lego/dataset/4490 brick bow 1x3 162R.png
#   inflating: lego/dataset/4490 brick bow 1x3 163L.png
#   inflating: lego/dataset/4490 brick bow 1x3 163R.png
#   inflating: lego/dataset/4490 brick bow 1x3 164L.png
#   inflating: lego/dataset/4490 brick bow 1x3 164R.png
#   inflating: lego/dataset/4490 brick bow 1x3 165L.png
#   inflating: lego/dataset/4490 brick bow 1x3 165R.png
#   inflating: lego/dataset/4490 brick bow 1x3 166L.png
#   inflating: lego/dataset/4490 brick bow 1x3 166R.png
#   inflating: lego/dataset/4490 brick bow 1x3 167L.png
#   inflating: lego/dataset/4490 brick bow 1x3 167R.png
#   inflating: lego/dataset/4490 brick bow 1x3 168L.png
#   inflating: lego/dataset/4490 brick bow 1x3 168R.png
#   inflating: lego/dataset/4490 brick bow 1x3 169L.png
#   inflating: lego/dataset/4490 brick bow 1x3 169R.png
#   inflating: lego/dataset/4490 brick bow 1x3 170L.png
#   inflating: lego/dataset/4490 brick bow 1x3 170R.png
#   inflating: lego/dataset/4490 brick bow 1x3 171L.png
#   inflating: lego/dataset/4490 brick bow 1x3 171R.png
#   inflating: lego/dataset/4490 brick bow 1x3 172L.png
#   inflating: lego/dataset/4490 brick bow 1x3 172R.png
#   inflating: lego/dataset/4490 brick bow 1x3 173L.png
#   inflating: lego/dataset/4490 brick bow 1x3 173R.png
#   inflating: lego/dataset/4490 brick bow 1x3 174L.png
#   inflating: lego/dataset/4490 brick bow 1x3 174R.png
#   inflating: lego/dataset/4490 brick bow 1x3 175L.png
#   inflating: lego/dataset/4490 brick bow 1x3 175R.png
#   inflating: lego/dataset/4490 brick bow 1x3 176L.png
#   inflating: lego/dataset/4490 brick bow 1x3 176R.png
#   inflating: lego/dataset/4490 brick bow 1x3 177L.png
#   inflating: lego/dataset/4490 brick bow 1x3 177R.png
#   inflating: lego/dataset/4490 brick bow 1x3 178L.png
#   inflating: lego/dataset/4490 brick bow 1x3 178R.png
#   inflating: lego/dataset/4490 brick bow 1x3 179L.png
#   inflating: lego/dataset/4490 brick bow 1x3 179R.png
#   inflating: lego/dataset/4490 brick bow 1x3 180L.png
#   inflating: lego/dataset/4490 brick bow 1x3 180R.png
#   inflating: lego/dataset/4490 brick bow 1x3 181L.png
#   inflating: lego/dataset/4490 brick bow 1x3 181R.png
#   inflating: lego/dataset/4490 brick bow 1x3 182L.png
#   inflating: lego/dataset/4490 brick bow 1x3 182R.png
#   inflating: lego/dataset/4490 brick bow 1x3 183L.png
#   inflating: lego/dataset/4490 brick bow 1x3 183R.png
#   inflating: lego/dataset/4490 brick bow 1x3 184L.png
#   inflating: lego/dataset/4490 brick bow 1x3 184R.png
#   inflating: lego/dataset/4490 brick bow 1x3 185L.png
#   inflating: lego/dataset/4490 brick bow 1x3 185R.png
#   inflating: lego/dataset/4490 brick bow 1x3 186L.png
#   inflating: lego/dataset/4490 brick bow 1x3 186R.png
#   inflating: lego/dataset/4490 brick bow 1x3 187L.png
#   inflating: lego/dataset/4490 brick bow 1x3 187R.png
#   inflating: lego/dataset/4490 brick bow 1x3 188L.png
#   inflating: lego/dataset/4490 brick bow 1x3 188R.png
#   inflating: lego/dataset/4490 brick bow 1x3 189L.png
#   inflating: lego/dataset/4490 brick bow 1x3 189R.png
#   inflating: lego/dataset/4490 brick bow 1x3 190L.png
#   inflating: lego/dataset/4490 brick bow 1x3 190R.png
#   inflating: lego/dataset/4490 brick bow 1x3 191L.png
#   inflating: lego/dataset/4490 brick bow 1x3 191R.png
#   inflating: lego/dataset/4490 brick bow 1x3 192L.png
#   inflating: lego/dataset/4490 brick bow 1x3 192R.png
#   inflating: lego/dataset/4490 brick bow 1x3 193L.png
#   inflating: lego/dataset/4490 brick bow 1x3 193R.png
#   inflating: lego/dataset/4490 brick bow 1x3 194L.png
#   inflating: lego/dataset/4490 brick bow 1x3 194R.png
#   inflating: lego/dataset/4490 brick bow 1x3 195L.png
#   inflating: lego/dataset/4490 brick bow 1x3 195R.png
#   inflating: lego/dataset/4490 brick bow 1x3 196L.png
#   inflating: lego/dataset/4490 brick bow 1x3 196R.png
#   inflating: lego/dataset/4490 brick bow 1x3 197L.png
#   inflating: lego/dataset/4490 brick bow 1x3 197R.png
#   inflating: lego/dataset/4490 brick bow 1x3 198L.png
#   inflating: lego/dataset/4490 brick bow 1x3 198R.png
#   inflating: lego/dataset/4490 brick bow 1x3 199L.png
#   inflating: lego/dataset/4490 brick bow 1x3 199R.png
#   inflating: lego/dataset/4490 brick bow 1x3 200L.png
#   inflating: lego/dataset/4490 brick bow 1x3 200R.png
#   inflating: lego/dataset/4490 brick bow 1x3 201L.png
#   inflating: lego/dataset/4490 brick bow 1x3 201R.png
#   inflating: lego/dataset/4490 brick bow 1x3 202L.png
#   inflating: lego/dataset/4490 brick bow 1x3 202R.png
#   inflating: lego/dataset/4490 brick bow 1x3 203L.png
#   inflating: lego/dataset/4490 brick bow 1x3 203R.png
#   inflating: lego/dataset/4490 brick bow 1x3 204L.png
#   inflating: lego/dataset/4490 brick bow 1x3 204R.png
#   inflating: lego/dataset/4490 brick bow 1x3 205L.png
#   inflating: lego/dataset/4490 brick bow 1x3 205R.png
#   inflating: lego/dataset/4490 brick bow 1x3 206L.png
#   inflating: lego/dataset/4490 brick bow 1x3 206R.png
#   inflating: lego/dataset/4490 brick bow 1x3 207L.png
#   inflating: lego/dataset/4490 brick bow 1x3 207R.png
#   inflating: lego/dataset/4490 brick bow 1x3 208L.png
#   inflating: lego/dataset/4490 brick bow 1x3 208R.png
#   inflating: lego/dataset/4490 brick bow 1x3 209L.png
#   inflating: lego/dataset/4490 brick bow 1x3 209R.png
#   inflating: lego/dataset/4490 brick bow 1x3 210L.png
#   inflating: lego/dataset/4490 brick bow 1x3 210R.png
#   inflating: lego/dataset/4490 brick bow 1x3 211L.png
#   inflating: lego/dataset/4490 brick bow 1x3 211R.png
#   inflating: lego/dataset/4490 brick bow 1x3 212L.png
#   inflating: lego/dataset/4490 brick bow 1x3 212R.png
#   inflating: lego/dataset/4490 brick bow 1x3 213L.png
#   inflating: lego/dataset/4490 brick bow 1x3 213R.png
#   inflating: lego/dataset/4490 brick bow 1x3 214L.png
#   inflating: lego/dataset/4490 brick bow 1x3 214R.png
#   inflating: lego/dataset/4490 brick bow 1x3 215L.png
#   inflating: lego/dataset/4490 brick bow 1x3 215R.png
#   inflating: lego/dataset/4490 brick bow 1x3 216L.png
#   inflating: lego/dataset/4490 brick bow 1x3 216R.png
#   inflating: lego/dataset/4490 brick bow 1x3 217L.png
#   inflating: lego/dataset/4490 brick bow 1x3 217R.png
#   inflating: lego/dataset/4490 brick bow 1x3 218L.png
#   inflating: lego/dataset/4490 brick bow 1x3 218R.png
#   inflating: lego/dataset/4490 brick bow 1x3 219L.png
#   inflating: lego/dataset/4490 brick bow 1x3 219R.png
#   inflating: lego/dataset/4490 brick bow 1x3 220L.png
#   inflating: lego/dataset/4490 brick bow 1x3 220R.png
#   inflating: lego/dataset/4490 brick bow 1x3 221L.png
#   inflating: lego/dataset/4490 brick bow 1x3 221R.png
#   inflating: lego/dataset/4490 brick bow 1x3 222L.png
#   inflating: lego/dataset/4490 brick bow 1x3 222R.png
#   inflating: lego/dataset/4490 brick bow 1x3 223L.png
#   inflating: lego/dataset/4490 brick bow 1x3 223R.png
#   inflating: lego/dataset/4490 brick bow 1x3 224L.png
#   inflating: lego/dataset/4490 brick bow 1x3 224R.png
#   inflating: lego/dataset/4490 brick bow 1x3 225L.png
#   inflating: lego/dataset/4490 brick bow 1x3 225R.png
#   inflating: lego/dataset/4490 brick bow 1x3 226L.png
#   inflating: lego/dataset/4490 brick bow 1x3 226R.png
#   inflating: lego/dataset/4490 brick bow 1x3 227L.png
#   inflating: lego/dataset/4490 brick bow 1x3 227R.png
#   inflating: lego/dataset/4490 brick bow 1x3 228L.png
#   inflating: lego/dataset/4490 brick bow 1x3 228R.png
#   inflating: lego/dataset/4490 brick bow 1x3 229L.png
#   inflating: lego/dataset/4490 brick bow 1x3 229R.png
#   inflating: lego/dataset/4490 brick bow 1x3 230L.png
#   inflating: lego/dataset/4490 brick bow 1x3 230R.png
#   inflating: lego/dataset/4490 brick bow 1x3 231L.png
#   inflating: lego/dataset/4490 brick bow 1x3 231R.png
#   inflating: lego/dataset/4490 brick bow 1x3 232L.png
#   inflating: lego/dataset/4490 brick bow 1x3 232R.png
#   inflating: lego/dataset/4490 brick bow 1x3 233L.png
#   inflating: lego/dataset/4490 brick bow 1x3 233R.png
#   inflating: lego/dataset/4490 brick bow 1x3 234L.png
#   inflating: lego/dataset/4490 brick bow 1x3 234R.png
#   inflating: lego/dataset/4490 brick bow 1x3 235L.png
#   inflating: lego/dataset/4490 brick bow 1x3 235R.png
#   inflating: lego/dataset/4490 brick bow 1x3 236L.png
#   inflating: lego/dataset/4490 brick bow 1x3 236R.png
#   inflating: lego/dataset/4490 brick bow 1x3 237L.png
#   inflating: lego/dataset/4490 brick bow 1x3 237R.png
#   inflating: lego/dataset/4490 brick bow 1x3 238L.png
#   inflating: lego/dataset/4490 brick bow 1x3 238R.png
#   inflating: lego/dataset/4490 brick bow 1x3 239L.png
#   inflating: lego/dataset/4490 brick bow 1x3 239R.png
#   inflating: lego/dataset/4490 brick bow 1x3 240L.png
#   inflating: lego/dataset/4490 brick bow 1x3 240R.png
#   inflating: lego/dataset/4490 brick bow 1x3 241L.png
#   inflating: lego/dataset/4490 brick bow 1x3 241R.png
#   inflating: lego/dataset/4490 brick bow 1x3 242L.png
#   inflating: lego/dataset/4490 brick bow 1x3 242R.png
#   inflating: lego/dataset/4490 brick bow 1x3 243L.png
#   inflating: lego/dataset/4490 brick bow 1x3 243R.png
#   inflating: lego/dataset/4490 brick bow 1x3 244L.png
#   inflating: lego/dataset/4490 brick bow 1x3 244R.png
#   inflating: lego/dataset/4490 brick bow 1x3 245L.png
#   inflating: lego/dataset/4490 brick bow 1x3 245R.png
#   inflating: lego/dataset/4490 brick bow 1x3 246L.png
#   inflating: lego/dataset/4490 brick bow 1x3 246R.png
#   inflating: lego/dataset/4490 brick bow 1x3 247L.png
#   inflating: lego/dataset/4490 brick bow 1x3 247R.png
#   inflating: lego/dataset/4490 brick bow 1x3 248L.png
#   inflating: lego/dataset/4490 brick bow 1x3 248R.png
#   inflating: lego/dataset/4490 brick bow 1x3 249L.png
#   inflating: lego/dataset/4490 brick bow 1x3 249R.png
#   inflating: lego/dataset/4490 brick bow 1x3 250L.png
#   inflating: lego/dataset/4490 brick bow 1x3 250R.png
#   inflating: lego/dataset/4490 brick bow 1x3 251L.png
#   inflating: lego/dataset/4490 brick bow 1x3 251R.png
#   inflating: lego/dataset/4490 brick bow 1x3 252L.png
#   inflating: lego/dataset/4490 brick bow 1x3 252R.png
#   inflating: lego/dataset/4490 brick bow 1x3 253L.png
#   inflating: lego/dataset/4490 brick bow 1x3 253R.png
#   inflating: lego/dataset/4490 brick bow 1x3 254L.png
#   inflating: lego/dataset/4490 brick bow 1x3 254R.png
#   inflating: lego/dataset/4490 brick bow 1x3 255L.png
#   inflating: lego/dataset/4490 brick bow 1x3 255R.png
#   inflating: lego/dataset/4490 brick bow 1x3 256L.png
#   inflating: lego/dataset/4490 brick bow 1x3 256R.png
#   inflating: lego/dataset/4490 brick bow 1x3 257L.png
#   inflating: lego/dataset/4490 brick bow 1x3 257R.png
#   inflating: lego/dataset/4490 brick bow 1x3 258L.png
#   inflating: lego/dataset/4490 brick bow 1x3 258R.png
#   inflating: lego/dataset/4490 brick bow 1x3 259L.png
#   inflating: lego/dataset/4490 brick bow 1x3 259R.png
#   inflating: lego/dataset/4490 brick bow 1x3 260L.png
#   inflating: lego/dataset/4490 brick bow 1x3 260R.png
#   inflating: lego/dataset/4490 brick bow 1x3 261L.png
#   inflating: lego/dataset/4490 brick bow 1x3 261R.png
#   inflating: lego/dataset/4490 brick bow 1x3 262L.png
#   inflating: lego/dataset/4490 brick bow 1x3 262R.png
#   inflating: lego/dataset/4490 brick bow 1x3 263L.png
#   inflating: lego/dataset/4490 brick bow 1x3 263R.png
#   inflating: lego/dataset/4490 brick bow 1x3 264L.png
#   inflating: lego/dataset/4490 brick bow 1x3 264R.png
#   inflating: lego/dataset/4490 brick bow 1x3 265L.png
#   inflating: lego/dataset/4490 brick bow 1x3 265R.png
#   inflating: lego/dataset/4490 brick bow 1x3 266L.png
#   inflating: lego/dataset/4490 brick bow 1x3 266R.png
#   inflating: lego/dataset/4490 brick bow 1x3 267L.png
#   inflating: lego/dataset/4490 brick bow 1x3 267R.png
#   inflating: lego/dataset/4490 brick bow 1x3 268L.png
#   inflating: lego/dataset/4490 brick bow 1x3 268R.png
#   inflating: lego/dataset/4490 brick bow 1x3 269L.png
#   inflating: lego/dataset/4490 brick bow 1x3 269R.png
#   inflating: lego/dataset/4490 brick bow 1x3 270L.png
#   inflating: lego/dataset/4490 brick bow 1x3 270R.png
#   inflating: lego/dataset/4490 brick bow 1x3 271L.png
#   inflating: lego/dataset/4490 brick bow 1x3 271R.png
#   inflating: lego/dataset/4490 brick bow 1x3 272L.png
#   inflating: lego/dataset/4490 brick bow 1x3 272R.png
#   inflating: lego/dataset/4490 brick bow 1x3 273L.png
#   inflating: lego/dataset/4490 brick bow 1x3 273R.png
#   inflating: lego/dataset/4490 brick bow 1x3 274L.png
#   inflating: lego/dataset/4490 brick bow 1x3 274R.png
#   inflating: lego/dataset/4490 brick bow 1x3 275L.png
#   inflating: lego/dataset/4490 brick bow 1x3 275R.png
#   inflating: lego/dataset/4490 brick bow 1x3 276L.png
#   inflating: lego/dataset/4490 brick bow 1x3 276R.png
#   inflating: lego/dataset/4490 brick bow 1x3 277L.png
#   inflating: lego/dataset/4490 brick bow 1x3 277R.png
#   inflating: lego/dataset/4490 brick bow 1x3 278L.png
#   inflating: lego/dataset/4490 brick bow 1x3 278R.png
#   inflating: lego/dataset/4490 brick bow 1x3 279L.png
#   inflating: lego/dataset/4490 brick bow 1x3 279R.png
#   inflating: lego/dataset/4490 brick bow 1x3 280L.png
#   inflating: lego/dataset/4490 brick bow 1x3 280R.png
#   inflating: lego/dataset/4490 brick bow 1x3 281L.png
#   inflating: lego/dataset/4490 brick bow 1x3 281R.png
#   inflating: lego/dataset/4490 brick bow 1x3 282L.png
#   inflating: lego/dataset/4490 brick bow 1x3 282R.png
#   inflating: lego/dataset/4490 brick bow 1x3 283L.png
#   inflating: lego/dataset/4490 brick bow 1x3 283R.png
#   inflating: lego/dataset/4490 brick bow 1x3 284L.png
#   inflating: lego/dataset/4490 brick bow 1x3 284R.png
#   inflating: lego/dataset/4490 brick bow 1x3 285L.png
#   inflating: lego/dataset/4490 brick bow 1x3 285R.png
#   inflating: lego/dataset/4490 brick bow 1x3 286L.png
#   inflating: lego/dataset/4490 brick bow 1x3 286R.png
#   inflating: lego/dataset/4490 brick bow 1x3 287L.png
#   inflating: lego/dataset/4490 brick bow 1x3 287R.png
#   inflating: lego/dataset/4490 brick bow 1x3 288L.png
#   inflating: lego/dataset/4490 brick bow 1x3 288R.png
#   inflating: lego/dataset/4490 brick bow 1x3 289L.png
#   inflating: lego/dataset/4490 brick bow 1x3 289R.png
#   inflating: lego/dataset/4490 brick bow 1x3 290L.png
#   inflating: lego/dataset/4490 brick bow 1x3 290R.png
#   inflating: lego/dataset/4490 brick bow 1x3 291L.png
#   inflating: lego/dataset/4490 brick bow 1x3 291R.png
#   inflating: lego/dataset/4490 brick bow 1x3 292L.png
#   inflating: lego/dataset/4490 brick bow 1x3 292R.png
#   inflating: lego/dataset/4490 brick bow 1x3 293L.png
#   inflating: lego/dataset/4490 brick bow 1x3 293R.png
#   inflating: lego/dataset/4490 brick bow 1x3 294L.png
#   inflating: lego/dataset/4490 brick bow 1x3 294R.png
#   inflating: lego/dataset/4490 brick bow 1x3 295L.png
#   inflating: lego/dataset/4490 brick bow 1x3 295R.png
#   inflating: lego/dataset/4490 brick bow 1x3 296L.png
#   inflating: lego/dataset/4490 brick bow 1x3 296R.png
#   inflating: lego/dataset/4490 brick bow 1x3 297L.png
#   inflating: lego/dataset/4490 brick bow 1x3 297R.png
#   inflating: lego/dataset/4490 brick bow 1x3 298L.png
#   inflating: lego/dataset/4490 brick bow 1x3 298R.png
#   inflating: lego/dataset/4490 brick bow 1x3 299L.png
#   inflating: lego/dataset/4490 brick bow 1x3 299R.png
#   inflating: lego/dataset/4490 brick bow 1x3 300L.png
#   inflating: lego/dataset/4490 brick bow 1x3 300R.png
#   inflating: lego/dataset/4490 brick bow 1x3 301L.png
#   inflating: lego/dataset/4490 brick bow 1x3 301R.png
#   inflating: lego/dataset/4490 brick bow 1x3 302L.png
#   inflating: lego/dataset/4490 brick bow 1x3 302R.png
#   inflating: lego/dataset/4490 brick bow 1x3 303L.png
#   inflating: lego/dataset/4490 brick bow 1x3 303R.png
#   inflating: lego/dataset/4490 brick bow 1x3 304L.png
#   inflating: lego/dataset/4490 brick bow 1x3 304R.png
#   inflating: lego/dataset/4490 brick bow 1x3 305L.png
#   inflating: lego/dataset/4490 brick bow 1x3 305R.png
#   inflating: lego/dataset/4490 brick bow 1x3 306L.png
#   inflating: lego/dataset/4490 brick bow 1x3 306R.png
#   inflating: lego/dataset/4490 brick bow 1x3 307L.png
#   inflating: lego/dataset/4490 brick bow 1x3 307R.png
#   inflating: lego/dataset/4490 brick bow 1x3 308L.png
#   inflating: lego/dataset/4490 brick bow 1x3 308R.png
#   inflating: lego/dataset/4490 brick bow 1x3 309L.png
#   inflating: lego/dataset/4490 brick bow 1x3 309R.png
#   inflating: lego/dataset/4490 brick bow 1x3 310L.png
#   inflating: lego/dataset/4490 brick bow 1x3 310R.png
#   inflating: lego/dataset/4490 brick bow 1x3 311L.png
#   inflating: lego/dataset/4490 brick bow 1x3 311R.png
#   inflating: lego/dataset/4490 brick bow 1x3 312L.png
#   inflating: lego/dataset/4490 brick bow 1x3 312R.png
#   inflating: lego/dataset/4490 brick bow 1x3 313L.png
#   inflating: lego/dataset/4490 brick bow 1x3 313R.png
#   inflating: lego/dataset/4490 brick bow 1x3 314L.png
#   inflating: lego/dataset/4490 brick bow 1x3 314R.png
#   inflating: lego/dataset/4490 brick bow 1x3 315L.png
#   inflating: lego/dataset/4490 brick bow 1x3 315R.png
#   inflating: lego/dataset/4490 brick bow 1x3 316L.png
#   inflating: lego/dataset/4490 brick bow 1x3 316R.png
#   inflating: lego/dataset/4490 brick bow 1x3 317L.png
#   inflating: lego/dataset/4490 brick bow 1x3 317R.png
#   inflating: lego/dataset/4490 brick bow 1x3 318L.png
#   inflating: lego/dataset/4490 brick bow 1x3 318R.png
#   inflating: lego/dataset/4490 brick bow 1x3 319L.png
#   inflating: lego/dataset/4490 brick bow 1x3 319R.png
#   inflating: lego/dataset/4490 brick bow 1x3 320L.png
#   inflating: lego/dataset/4490 brick bow 1x3 320R.png
#   inflating: lego/dataset/4490 brick bow 1x3 321L.png
#   inflating: lego/dataset/4490 brick bow 1x3 321R.png
#   inflating: lego/dataset/4490 brick bow 1x3 322L.png
#   inflating: lego/dataset/4490 brick bow 1x3 322R.png
#   inflating: lego/dataset/4490 brick bow 1x3 323L.png
#   inflating: lego/dataset/4490 brick bow 1x3 323R.png
#   inflating: lego/dataset/4490 brick bow 1x3 324L.png
#   inflating: lego/dataset/4490 brick bow 1x3 324R.png
#   inflating: lego/dataset/4490 brick bow 1x3 325L.png
#   inflating: lego/dataset/4490 brick bow 1x3 325R.png
#   inflating: lego/dataset/4490 brick bow 1x3 326L.png
#   inflating: lego/dataset/4490 brick bow 1x3 326R.png
#   inflating: lego/dataset/4490 brick bow 1x3 327L.png
#   inflating: lego/dataset/4490 brick bow 1x3 327R.png
#   inflating: lego/dataset/4490 brick bow 1x3 328L.png
#   inflating: lego/dataset/4490 brick bow 1x3 328R.png
#   inflating: lego/dataset/4490 brick bow 1x3 329L.png
#   inflating: lego/dataset/4490 brick bow 1x3 329R.png
#   inflating: lego/dataset/4490 brick bow 1x3 330L.png
#   inflating: lego/dataset/4490 brick bow 1x3 330R.png
#   inflating: lego/dataset/4490 brick bow 1x3 331L.png
#   inflating: lego/dataset/4490 brick bow 1x3 331R.png
#   inflating: lego/dataset/4490 brick bow 1x3 332L.png
#   inflating: lego/dataset/4490 brick bow 1x3 332R.png
#   inflating: lego/dataset/4490 brick bow 1x3 333L.png
#   inflating: lego/dataset/4490 brick bow 1x3 333R.png
#   inflating: lego/dataset/4490 brick bow 1x3 334L.png
#   inflating: lego/dataset/4490 brick bow 1x3 334R.png
#   inflating: lego/dataset/4490 brick bow 1x3 335L.png
# ...
#   inflating: lego/dataset/99301 roof tile inside 3x3 275R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 276L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 276R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 277L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 277R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 278L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 278R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 279L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 279R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 280L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 280R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 281L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 281R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 282L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 282R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 283L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 283R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 284L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 284R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 285L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 285R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 286L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 286R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 287L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 287R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 288L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 288R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 289L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 289R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 290L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 290R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 291L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 291R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 292L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 292R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 293L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 293R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 294L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 294R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 295L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 295R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 296L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 296R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 297L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 297R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 298L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 298R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 299L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 299R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 300L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 300R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 301L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 301R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 302L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 302R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 303L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 303R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 304L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 304R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 305L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 305R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 306L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 306R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 307L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 307R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 308L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 308R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 309L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 309R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 310L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 310R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 311L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 311R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 312L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 312R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 313L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 313R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 314L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 314R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 315L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 315R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 316L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 316R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 317L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 317R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 318L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 318R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 319L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 319R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 320L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 320R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 321L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 321R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 322L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 322R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 323L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 323R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 324L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 324R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 325L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 325R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 326L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 326R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 327L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 327R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 328L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 328R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 329L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 329R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 330L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 330R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 331L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 331R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 332L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 332R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 333L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 333R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 334L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 334R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 335L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 335R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 336L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 336R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 337L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 337R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 338L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 338R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 339L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 339R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 340L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 340R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 341L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 341R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 342L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 342R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 343L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 343R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 344L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 344R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 345L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 345R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 346L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 346R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 347L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 347R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 348L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 348R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 349L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 349R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 350L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 350R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 351L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 351R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 352L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 352R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 353L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 353R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 354L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 354R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 355L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 355R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 356L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 356R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 357L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 357R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 358L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 358R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 359L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 359R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 360L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 360R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 361L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 361R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 362L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 362R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 363L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 363R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 364L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 364R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 365L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 365R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 366L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 366R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 367L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 367R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 368L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 368R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 369L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 369R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 370L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 370R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 371L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 371R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 372L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 372R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 373L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 373R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 374L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 374R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 375L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 375R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 376L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 376R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 377L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 377R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 378L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 378R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 379L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 379R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 380L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 380R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 381L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 381R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 382L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 382R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 383L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 383R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 384L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 384R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 385L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 385R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 386L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 386R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 387L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 387R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 388L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 388R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 389L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 389R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 390L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 390R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 391L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 391R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 392L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 392R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 393L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 393R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 394L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 394R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 395L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 395R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 396L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 396R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 397L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 397R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 398L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 398R.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 399L.png
#   inflating: lego/dataset/99301 roof tile inside 3x3 399R.png
#   inflating: lego/validation.txt

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import (
    layers,
    models,
    callbacks,
    losses,
    utils,
    metrics,
    optimizers,
)
from utils import display, sample_batch

# %%
# utils.py가 필요 (display할때)

# %%
IMAGE_SIZE = 64
CHANNELS = 1
BATCH_SIZE = 128
Z_DIM = 100
EPOCHS = 100 # 훈련이 오래 걸려 에포크 횟수를 300에서 100으로 줄입니다.
LOAD_MODEL = False
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.999
LEARNING_RATE = 0.0002
NOISE_PARAM = 0.1

# %%
# 텐서플로 데이터 셋 만들기
from glob import glob
temp =  glob('/content/lego/dataset/*');
[paths for paths in temp if paths.split('.')[-1] !='png']
# Out:
# []

# %%
from PIL import Image
Image.open(temp[-1])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x400>

# %%
train_data = utils.image_dataset_from_directory(
    '/content/lego/dataset/',
    labels = None,
    image_size=(64,64),
    batch_size=128,
    shuffle = True,
    seed=42,
    color_mode='grayscale'
)
# Out:
# Found 40000 files belonging to 1 classes.

# %%
# 데이터 전처리
# 원본데이터 : 0 ~ 255
# GAN을 훈련할때는 데이터 -1 ~ 1 범위로 스케일 --> 마지막층 시그모이드
# 대신에 더 강한 그레이디언트 tanh를 사용하기 위해서
def preprocess(img):
  img = (tf.cast(img,'float32')-127.5 / 127.5)
  return img

train = train_data.map(lambda x : preprocess(x))

# %%
# 이지미 시각화
train_sample = sample_batch(train)
display(train_sample)

# %%
# 판별자  생성
# inputlayer - conv2d - leakyrelu -dropuout

# conv2d - batchnormal- leakyrelu -dropuout
# conv2d - batchnormal- leakyrelu -dropuout
# conv2d - batchnormal- leakyrelu -dropuout

# conv2d - flattern

# %%
discriminator_input = layers.Input(shape=(64,64,1))
# 바이어스 false로 하면 학습파라메터가 감소, 계산효율성증가, 특정 데이터나 문제에 따라서 성능이 향상
x = layers.Conv2D(64,kernel_size=4,strides=2,padding='same',use_bias=False)(discriminator_input)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(128,kernel_size=4,strides=2,padding='same',use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(256,kernel_size=4,strides=2,padding='same',use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(512,kernel_size=4,strides=2,padding='same',use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(1,kernel_size=4,strides=1,padding='valid',use_bias=False, activation='sigmoid')(x)
discriminator_output = layers.Flatten()(x)
discriminator = models.Model(discriminator_input,discriminator_output)  # Dense층을 사용하지 않는 이유는 (None, 1, 1, 1)
discriminator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 64)        1024
#
#  leaky_re_lu (LeakyReLU)     (None, 32, 32, 64)        0
#
#  dropout (Dropout)           (None, 32, 32, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 128)       131072
#
#  batch_normalization (Batch  (None, 16, 16, 128)       512
#  Normalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  dropout_1 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 256)         524288
#
#  batch_normalization_1 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 8, 256)         0
#
#  dropout_2 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 512)         2097152
#
#  batch_normalization_2 (Bat  (None, 4, 4, 512)         2048
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 4, 4, 512)         0
#
#  dropout_3 (Dropout)         (None, 4, 4, 512)         0
#
#  conv2d_4 (Conv2D)           (None, 1, 1, 1)           8192
#
#  flatten (Flatten)           (None, 1)                 0
#
# =================================================================
# Total params: 2765312 (10.55 MB)
# Trainable params: 2763520 (10.54 MB)
# Non-trainable params: 1792 (7.00 KB)
# _________________________________________________________________

# %%
# 생성자의 입력은 VAE와 동일한 목적으로
# 생성자
generator_input = layers.Input(shape=(100,))  # input층은 길이가 100인 벡터
x = layers.Reshape( (1,1,100))(generator_input)
x = layers.Conv2DTranspose(512,kernel_size=4,strides=1, padding='valid', use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(256,kernel_size=4,strides=2, padding='same', use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(128,kernel_size=4,strides=2, padding='same', use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(64,kernel_size=4,strides=2, padding='same', use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)

generator_output = layers.Conv2DTranspose(1,kernel_size=4,strides=2, padding='same', use_bias=False, activation='tanh')(x)
generator = models.Model(generator_input,generator_output)
generator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100)]             0
#
#  reshape (Reshape)           (None, 1, 1, 100)         0
#
#  conv2d_transpose (Conv2DTr  (None, 4, 4, 512)         819200
#  anspose)
#
#  batch_normalization_3 (Bat  (None, 4, 4, 512)         2048
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 4, 4, 512)         0
#
#  conv2d_transpose_1 (Conv2D  (None, 8, 8, 256)         2097152
#  Transpose)
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 8, 8, 256)         0
#
#  conv2d_transpose_2 (Conv2D  (None, 16, 16, 128)       524288
#  Transpose)
#
#  batch_normalization_5 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  conv2d_transpose_3 (Conv2D  (None, 32, 32, 64)        131072
#  Transpose)
#
#  batch_normalization_6 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 64)        0
#
#  conv2d_transpose_4 (Conv2D  (None, 64, 64, 1)         1024
#  Transpose)
#
# =================================================================
# Total params: 3576576 (13.64 MB)
# Trainable params: 3574656 (13.64 MB)
# Non-trainable params: 1920 (7.50 KB)
# _________________________________________________________________

# %%
# 훈련세트의 진짜 샘플과 생성자의 출력을 합쳐서 훈련세트를 만들어서 판별자를 훈련 - 지도학습
# 진짜는 레이블 1, 가짜는 레이블 0, 바이너리 크로스 엔트로피

# 생성자훈련 : 생성된 이미지에 점수를 부여하고 높은 점수를 낸 이미지로 최적화하는 방법 --> 판별자
# 판별자가 진짜라고 생각하는 이미지를 생성하도록 생성자를 훈련

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class DCGAN(models.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(DCGAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    def compile(self, d_optimizer, g_optimizer):
        super(DCGAN, self).compile()
        self.loss_fn = losses.BinaryCrossentropy() # 생성자와 판별자의 손실함수는 이진 크로스 엔트로피
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss_metric = metrics.Mean(name="d_loss")
        self.d_real_acc_metric = metrics.BinaryAccuracy(name="d_real_acc")
        self.d_fake_acc_metric = metrics.BinaryAccuracy(name="d_fake_acc")
        self.d_acc_metric = metrics.BinaryAccuracy(name="d_acc")
        self.g_loss_metric = metrics.Mean(name="g_loss")
        self.g_acc_metric = metrics.BinaryAccuracy(name="g_acc")

    @property
    def metrics(self):
        return [
            self.d_loss_metric,
            self.d_real_acc_metric,
            self.d_fake_acc_metric,
            self.d_acc_metric,
            self.g_loss_metric,
            self.g_acc_metric,
        ]

    def train_step(self, real_images):
        # 잠재 공간에서 랜덤 포인트 샘플링
        batch_size = tf.shape(real_images)[0]
        random_latent_vectors = tf.random.normal(
            shape=(batch_size, self.latent_dim)
        )  # 다변량 표준 정규분포에서 배치 벡터를 샘플링

        # 가짜 이미지로 판별자 훈련하기
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            generated_images = self.generator(
                random_latent_vectors, training=True
            )
            real_predictions = self.discriminator(real_images, training=True)
            fake_predictions = self.discriminator(
                generated_images, training=True
            )# 생성자에 전달해서 이미지 배치를 생성

            real_labels = tf.ones_like(real_predictions)
            real_noisy_labels = real_labels + NOISE_PARAM * tf.random.uniform(
                tf.shape(real_predictions)
            )
            fake_labels = tf.zeros_like(fake_predictions)
            fake_noisy_labels = fake_labels - NOISE_PARAM * tf.random.uniform(
                tf.shape(fake_predictions)
            )

            d_real_loss = self.loss_fn(real_noisy_labels, real_predictions)
            d_fake_loss = self.loss_fn(fake_noisy_labels, fake_predictions)
            d_loss = (d_real_loss + d_fake_loss) / 2.0

            g_loss = self.loss_fn(real_labels, fake_predictions)

        gradients_of_discriminator = disc_tape.gradient(
            d_loss, self.discriminator.trainable_variables
        )
        gradients_of_generator = gen_tape.gradient(
            g_loss, self.generator.trainable_variables
        )

        self.d_optimizer.apply_gradients(
            zip(gradients_of_discriminator, discriminator.trainable_variables)
        )
        self.g_optimizer.apply_gradients(
            zip(gradients_of_generator, generator.trainable_variables)
        )

        # 메트릭 업데이트
        self.d_loss_metric.update_state(d_loss)
        self.d_real_acc_metric.update_state(real_labels, real_predictions)
        self.d_fake_acc_metric.update_state(fake_labels, fake_predictions)
        self.d_acc_metric.update_state(
            [real_labels, fake_labels], [real_predictions, fake_predictions]
        )
        self.g_loss_metric.update_state(g_loss)
        self.g_acc_metric.update_state(real_labels, fake_predictions)

        return {m.name: m.result() for m in self.metrics}

# %%
# 모델 생성
dcgan = DCGAN(discriminator,generator,latent_dim=Z_DIM)

# %%
dcgan.compile(
    d_optimizer=optimizers.Adam(learning_rate=LEARNING_RATE, beta_1=ADAM_BETA_1,beta_2 = ADAM_BETA_2),
    g_optimizer=optimizers.Adam(learning_rate=LEARNING_RATE, beta_1=ADAM_BETA_1,beta_2 = ADAM_BETA_2),
)

# %%
# 모델 저장 체크포인트
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath = '/content/drive/MyDrive/lego_block_data/checkpoint.ckpt',
    save_weights_only=True,
    save_freq = 'epoch',
    verbose=0
)
tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")


class ImageGenerator(callbacks.Callback):
    def __init__(self, num_img, latent_dim):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 3 == 0: # 출력 횟수를 줄이기 위해
            random_latent_vectors = tf.random.normal(
                shape=(self.num_img, self.latent_dim)
            )
            generated_images = self.model.generator(random_latent_vectors)
            generated_images = generated_images * 127.5 + 127.5
            generated_images = generated_images.numpy()
            display(
                generated_images,
                save_to="/content/drive/MyDrive/lego_block_data/generated_img_%03d.png" % (epoch),
            )

# %%
dcgan.fit(
    train,
    # epochs = EPOCHS,
    epochs = 10,
    callbacks=[
        model_checkpoint_callback,
        tensorboard_callback,
        ImageGenerator(num_img=10,latent_dim=Z_DIM)
    ]
)
# Out:
# Epoch 1/10
# 313/313 [==============================] - ETA: 0s - d_loss: -0.6547 - d_real_acc: 0.9925 - d_fake_acc: 0.9925 - d_acc: 0.9925 - g_loss: 13.7874 - g_acc: 0.0075
# Saved to /content/drive/MyDrive/lego_block_data/generated_img_000.png
# 313/313 [==============================] - 97s 253ms/step - d_loss: -0.6547 - d_real_acc: 0.9925 - d_fake_acc: 0.9925 - d_acc: 0.9925 - g_loss: 13.7874 - g_acc: 0.0075
# Epoch 2/10
# 313/313 [==============================] - 79s 247ms/step - d_loss: -0.7663 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4125 - g_acc: 0.0000e+00
# Epoch 3/10
# 313/313 [==============================] - 78s 244ms/step - d_loss: -0.7675 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4224 - g_acc: 0.0000e+00
# Epoch 4/10
# 313/313 [==============================] - ETA: 0s - d_loss: -0.7672 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4236 - g_acc: 0.0000e+00
# Saved to /content/drive/MyDrive/lego_block_data/generated_img_003.png
# 313/313 [==============================] - 79s 247ms/step - d_loss: -0.7672 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4236 - g_acc: 0.0000e+00
# Epoch 5/10
# 313/313 [==============================] - 81s 249ms/step - d_loss: -0.7660 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4244 - g_acc: 0.0000e+00
# Epoch 6/10
# 313/313 [==============================] - 80s 250ms/step - d_loss: -0.7669 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4243 - g_acc: 0.0000e+00
# Epoch 7/10
# 313/313 [==============================] - ETA: 0s - d_loss: -0.7666 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4247 - g_acc: 0.0000e+00
# Saved to /content/drive/MyDrive/lego_block_data/generated_img_006.png
# 313/313 [==============================] - 79s 247ms/step - d_loss: -0.7666 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4247 - g_acc: 0.0000e+00
# Epoch 8/10
# 313/313 [==============================] - 79s 247ms/step - d_loss: -0.7676 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4246 - g_acc: 0.0000e+00
# Epoch 9/10
# 313/313 [==============================] - 80s 247ms/step - d_loss: -0.7643 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4247 - g_acc: 0.0000e+00
# Epoch 10/10
# 313/313 [==============================] - ETA: 0s - d_loss: -0.7652 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4249 - g_acc: 0.0000e+00
# Saved to /content/drive/MyDrive/lego_block_data/generated_img_009.png
# 313/313 [==============================] - 80s 252ms/step - d_loss: -0.7652 - d_real_acc: 1.0000 - d_fake_acc: 1.0000 - d_acc: 1.0000 - g_loss: 15.4249 - g_acc: 0.0000e+00

# %%
# 모델저장
generator.save('/content/drive/MyDrive/lego_block_data/model/generator')
discriminator.save('/content/drive/MyDrive/lego_block_data/model/discriminator')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# 새로운 이미지 생성 : 표준정규분포에서 잠재 공간의 일부 포인트를 샘플링
grid_width,grid_height = (10,3)
z_sample =  np.random.normal(size=(grid_width*grid_height,Z_DIM))

# %%
# 샘플링 된 포인트를 디코딩
reconstructions = generator.predict(z_sample)
# Out:
# 1/1 [==============================] - 0s 417ms/step

# %%
# 디코딩된 이미지 그리기
fig = plt.figure(figsize=(18,5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_width * grid_height):
  ax = fig.add_subplot(grid_height, grid_width, i+1)
  ax.axis("off")
  ax.imshow(reconstructions[i, : , : ], cmap='gray')

# %%
# 문제점
# 판별자가 생성자 보다 훨씬 뛰어난 경우
# 판별자가 너무 강하면 손실함수의 신호가 너무 약해져서 생성자의 의미 있는 향상을 기대하기 어렵다.
# 그레이디언트가 사라져서 학습이 전혀 이루어지지 않을수 있다

# 판별자에 있는 Droupout층의 rate 매개변수 값을 증가 네트웍에 흐르는 정보의 양을 줄여준다
# 판별자의 학습을 줄인다
# 판별자의 합성곱 필터수를 줄인다
# 판별자를 훈련할때 레이블에 잡음을 추가
# 판별자를 훈련할때 일부 이미지의 레이블을 무작위로 뒤집는다

# %%
# 생성자가 판별자보다 훨씬 뛰어난 경우
# 모드붕괴 mode collapse
# 판별자의 가중치를 업데이트하지 않고 몇번의 배치를 하는 동안 생성자를 훈련한다고 가정하면
# 생성자가 샘플... 판별자를 항상속이는 샘플(모드 model)
# 잠재공간에 있는 모든 포인트를 매핑못하고 손실함수의 그레이디언트가 0에 가깝게 붕괴
