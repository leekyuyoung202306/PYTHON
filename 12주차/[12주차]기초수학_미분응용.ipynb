# %% [markdown]
# - 미분의 기본공식
# - 합법칙
# - 차법칙
# - 곱법칙
# - 몫법칙
# - 연쇄법칙

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 미분법칙
#   - y는 u의 함수이고 u는 x의 함수
#   - y= f(u), u = g(x)
#
#
#   ![image.png](data:image/png;base64,...)

# %%
# 편의점에서 500짜리 음료수 2개를 구입
# 부가세는 10%
# 지불하는 금액

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 초기화
input_size = 2
hidden_size = 3
output_size = 1

# %%
# 가중치 초기화
import numpy as np
# 입력값과 은닉층사이
w1 = np.random.randn(input_size,hidden_size)
b1 = np.zeros((1,hidden_size))
print(w1.shape, b1.shape)

# 은닉층과 출력층사이
w2 = np.random.randn(hidden_size,output_size)
b2 = np.zeros((1,output_size))
print(w2.shape, b2.shape)
# Out:
# (2, 3) (1, 3)
# (3, 1) (1, 1)

# %%
def sigmoid(x):
  return 1 / (1+np.exp(-x))

# %%
# 시그모이드 미분함수
def sigmoid_derivative(x):
  return x * (1 - x)

# %%
# 입력데이터와 출력데이터 정의(AND 게이트)
