# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 데이터프레임(DataFrame)
#   - 시리즈(Series)집합

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
data = {
    '이름' : ['유정','유나','민영','은지'],
    '나이' : [30,28,31,29],
    '생일' : ['1991.5.2','1993.4.6','1990.9.12','1992.7.19']
}
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#    이름  나이         생일
# 0  유정  30   1991.5.2
# 1  유나  28   1993.4.6
# 2  민영  31  1990.9.12
# 3  은지  29  1992.7.19

# %%
df1.columns
# Out:
# Index(['이름', '나이', '생일'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df2 = pd.DataFrame(data,index=['하나','둘','셋','넷'])
df2
# Out:
#     이름  나이         생일
# 하나  유정  30   1991.5.2
# 둘   유나  28   1993.4.6
# 셋   민영  31  1990.9.12
# 넷   은지  29  1992.7.19

# %%
df2.index
# Out:
# Index(['하나', '둘', '셋', '넷'], dtype='object')

# %%
sr_name = df2['이름']
print(sr_name)
type(sr_name)
# Out:
# 하나    유정
# 둘     유나
# 셋     민영
# 넷     은지
# Name: 이름, dtype: object
# pandas.core.series.Series

# %%
sr_name = df2[['이름','생일']]
sr_name
# Out:
#     이름         생일
# 하나  유정   1991.5.2
# 둘   유나   1993.4.6
# 셋   민영  1990.9.12
# 넷   은지  1992.7.19

# %%
sr_name = df2[['이름']]
sr_name
# Out:
#     이름
# 하나  유정
# 둘   유나
# 셋   민영
# 넷   은지

# %%
# df2.loc, df2.iloc  --> 행렬의 개념... [행,열]
df2
# Out:
#     이름  나이         생일
# 하나  유정  30   1991.5.2
# 둘   유나  28   1993.4.6
# 셋   민영  31  1990.9.12
# 넷   은지  29  1992.7.19

# %%
sr_two = df2.loc[['넷','둘']]
sr_two
# Out:
#    이름  나이         생일
# 넷  은지  29  1992.7.19
# 둘  유나  28   1993.4.6

# %%
df2.loc['넷','생일']   # df2.loc[['넷','생일']]
# Out:
# '1992.7.19'

# %%
df2.iloc[0,0]
# Out:
# '유정'

# %%
df2['시력'] = [1.0,2.0,1.5,0.5]
df2
# Out:
#     이름  나이         생일   시력
# 하나  유정  30   1991.5.2  1.0
# 둘   유나  28   1993.4.6  2.0
# 셋   민영  31  1990.9.12  1.5
# 넷   은지  29  1992.7.19  0.5

# %%
df2.loc['다섯'] =['길동', 22, '1990.1.1',0.8]
df2
# Out:
#     이름  나이         생일   시력
# 하나  유정  30   1991.5.2  1.0
# 둘   유나  28   1993.4.6  2.0
# 셋   민영  31  1990.9.12  1.5
# 넷   은지  29  1992.7.19  0.5
# 다섯  길동  22   1990.1.1  0.8

# %% [markdown]
# 판다스의 리스트 슬라이싱

# %%
df2.loc[ : , : '나이' ]
# Out:
#     이름  나이
# 하나  유정  30
# 둘   유나  28
# 셋   민영  31
# 넷   은지  29
# 다섯  길동  22

# %%
df2.iloc[1:, : 2]
# Out:
#     이름  나이
# 둘   유나  28
# 셋   민영  31
# 넷   은지  29
# 다섯  길동  22

# %%
df2
# Out:
#     이름  나이         생일   시력
# 하나  유정  30   1991.5.2  1.0
# 둘   유나  28   1993.4.6  2.0
# 셋   민영  31  1990.9.12  1.5
# 넷   은지  29  1992.7.19  0.5
# 다섯  길동  22   1990.1.1  0.8

# %%
df2.loc[ '셋':'넷' ,'이름' :'생일'  ]
# Out:
#    이름  나이         생일
# 셋  민영  31  1990.9.12
# 넷  은지  29  1992.7.19

# %%
df2.iloc[2 :4  , : 3 ]
# Out:
#    이름  나이         생일
# 셋  민영  31  1990.9.12
# 넷  은지  29  1992.7.19

# %% [markdown]
# CSV 파일 읽어오기

# %%
import pandas as pd
df = pd.read_csv('/content/소상공인시장진흥공단_서울 개업 현황_20171016.csv',encoding='cp949')

# %%
df
# Out:
#              상호명                     주소 업종대분류    업종중분류      업종소분류
# 0           허술한집    서울특별시 강서구 공항동 45-89    음식       분식     라면김밥분식
# 1           신풍유통     서울특별시 중구 봉래동2가 122    제조  식품가공/제조     종합식품제조
# 2           옛날한과   서울특별시 양천구 신월동 115-15    음식  제과제빵떡케익      떡/한과집
# 3      서울연인단팥빵본점    서울특별시 강남구 역삼동 707-9    제조  식품가공/제조  빵/과자제조-종합
# 4             엔젤     서울특별시 중구 황학동 706-2    음식     유흥주점      호프/맥주
# ...          ...                    ...   ...      ...        ...
# 21386      함.무바라   서울특별시 서대문구 창천동 30-33    제조  식품가공/제조     종합식품제조
# 21387  라면국물편의점포차  서울특별시 마포구 서교동 358-124    소매    종합소매점        편의점
# 21388       뚜레쥬르  서울특별시 관악구 신림동 1641-21    음식  제과제빵떡케익        제과점
# 21389        백야드    서울특별시 마포구 동교동 158-6    음식       양식   정통양식/경양식
# 21390    천기초조은웰빙      서울특별시 금천구 독산동 985   NaN      NaN        NaN
#
# [21391 rows x 5 columns]

# %%
df.head()
# Out:
#          상호명                    주소 업종대분류    업종중분류      업종소분류
# 0       허술한집   서울특별시 강서구 공항동 45-89    음식       분식     라면김밥분식
# 1       신풍유통    서울특별시 중구 봉래동2가 122    제조  식품가공/제조     종합식품제조
# 2       옛날한과  서울특별시 양천구 신월동 115-15    음식  제과제빵떡케익      떡/한과집
# 3  서울연인단팥빵본점   서울특별시 강남구 역삼동 707-9    제조  식품가공/제조  빵/과자제조-종합
# 4         엔젤    서울특별시 중구 황학동 706-2    음식     유흥주점      호프/맥주

# %%
df.tail()
# Out:
#              상호명                     주소 업종대분류    업종중분류     업종소분류
# 21386      함.무바라   서울특별시 서대문구 창천동 30-33    제조  식품가공/제조    종합식품제조
# 21387  라면국물편의점포차  서울특별시 마포구 서교동 358-124    소매    종합소매점       편의점
# 21388       뚜레쥬르  서울특별시 관악구 신림동 1641-21    음식  제과제빵떡케익       제과점
# 21389        백야드    서울특별시 마포구 동교동 158-6    음식       양식  정통양식/경양식
# 21390    천기초조은웰빙      서울특별시 금천구 독산동 985   NaN      NaN       NaN

# %%
df.head(3).T
# Out:
#                          0                   1                     2
# 상호명                   허술한집                신풍유통                  옛날한과
# 주소     서울특별시 강서구 공항동 45-89  서울특별시 중구 봉래동2가 122  서울특별시 양천구 신월동 115-15
# 업종대분류                   음식                  제조                    음식
# 업종중분류                   분식             식품가공/제조               제과제빵떡케익
# 업종소분류               라면김밥분식              종합식품제조                 떡/한과집

# %%
df2 = df[['상호명','업종대분류']]

# %% [markdown]
# csv파일에서 데이터 읽기
#   - df = pd.read_csv(파일경로포함파일명)
#   - df.head() : 앞에서 5개
#   - df.tail() : 뒤에서 5개
#   - df['이름'] : 해당 컬럼의 데이터
#   - df[슬라이싱형태] : 슬라이싱에 해당하는 row 열  슬라이싱이 가능

# %%
df2[:2]
# Out:
#     상호명 업종대분류
# 0  허술한집    음식
# 1  신풍유통    제조

# %%
df[['상호명','업종대분류']][:2]
# Out:
#     상호명 업종대분류
# 0  허술한집    음식
# 1  신풍유통    제조

# %%
df.columns = ['상호명', '주소', '대분류', '중분류', '소분류']

# %%
df.head()
# Out:
#          상호명                    주소 대분류      중분류        소분류
# 0       허술한집   서울특별시 강서구 공항동 45-89  음식       분식     라면김밥분식
# 1       신풍유통    서울특별시 중구 봉래동2가 122  제조  식품가공/제조     종합식품제조
# 2       옛날한과  서울특별시 양천구 신월동 115-15  음식  제과제빵떡케익      떡/한과집
# 3  서울연인단팥빵본점   서울특별시 강남구 역삼동 707-9  제조  식품가공/제조  빵/과자제조-종합
# 4         엔젤    서울특별시 중구 황학동 706-2  음식     유흥주점      호프/맥주

# %%
df.index = df['상호명']

# %%
df.head()
# Out:
#                              주소 대분류      중분류        소분류
# 상호명
# 허술한집        서울특별시 강서구 공항동 45-89  음식       분식     라면김밥분식
# 신풍유통         서울특별시 중구 봉래동2가 122  제조  식품가공/제조     종합식품제조
# 옛날한과       서울특별시 양천구 신월동 115-15  음식  제과제빵떡케익      떡/한과집
# 서울연인단팥빵본점   서울특별시 강남구 역삼동 707-9  제조  식품가공/제조  빵/과자제조-종합
# 엔젤           서울특별시 중구 황학동 706-2  음식     유흥주점      호프/맥주

# %%
# df = df.drop(columns=['상호명'])
df.loc[['서울연인단팥빵본점'] ,['주소','소분류'] ]
# Out:
#                             주소        소분류
# 상호명
# 서울연인단팥빵본점  서울특별시 강남구 역삼동 707-9  빵/과자제조-종합
